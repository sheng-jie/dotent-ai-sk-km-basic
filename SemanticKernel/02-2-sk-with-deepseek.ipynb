// %% [markdown]
// [](./Resources/ai-sk-add-wechat.png)

// %% [markdown]
// # Semantic Kernel 对接 DeepSeek
//
// 上一节课我们以智谱为例，介绍了如何对接国内大模型。DeepSeek 作为国内首屈一指的大模型服务提供商，提供了R1、V3等优秀的大模型。Semantic Kernel该如何对接呢？
//
// 首先需要确认DeepSeek API是否兼容OpenAI API的格式。
//
// 在官方DeepSeek API 文档中（https://api-docs.deepseek.com/zh-cn/）， 我们找到了答案：
//
// ![deepseek api doc](attachment:image.png)

// %% [markdown]
// ## 注册 DeepSeek
//
// 1. 注册：点击 [https://platform.deepseek.com](https://platform.deepseek.com) 即可访问DeepSeek开放平台。
//
// 2. 点击充值菜单，充值，按需充值。
//
// 3. 生成API Key：依次点击 API keys-> 创建API Key -> 复制 API KEY 待用 。

// %% [markdown]
// ## 使用DeepSeek 大模型
//
// 由于DeepSeek API 兼容OpenAI 的API 格式，因此可以直接使用以下两种方式快速开始：
// 1. 指定自定义`Endpoint` 实现。
// 2. 指定自定义`OpenAIClient`。

// %%
#r "nuget: Microsoft.SemanticKernel"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.SemanticKernel, 1.47.0</span></li></ul></div></div>

// %% [markdown]
// ### 指定自定义 Endpoint

// %%
// #pragma warning disable SKEXP0010

using Microsoft.SemanticKernel;
using Microsoft.SemanticKernel.ChatCompletion;
using Microsoft.SemanticKernel.Connectors.OpenAI;
using Microsoft.Extensions.DependencyInjection;

// 引入交互式的内核命名空间，以便用户输入
using PolyglotKernel= Microsoft.DotNet.Interactive.Kernel;

// var deepseekApiKey = await PolyglotKernel.GetInputAsync("请输入您的API Key："); 
var deepseekApiKey = "sk-de7d2bdb6f1b428ea23d4c4b8176b6dc";

// Create kernel builder
var builder = Kernel.CreateBuilder();

var endpoint = new Uri("https://api.deepseek.com");
// Add OpenAI Chat completion
builder.AddOpenAIChatCompletion(
    modelId: "deepseek-chat", // 可选模型编码：deepseek-chat、deepseek-reasoner（推理）
    apiKey: deepseekApiKey,
    endpoint: endpoint);
// Build kernel
var kernel = builder.Build();

var response = await kernel.InvokePromptAsync("介绍下DeepSeek的产品和服务");
response.Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>DeepSeek（深度求索）是一家专注于人工智能技术研发的公司，致力于提供高效、智能的大模型及相关产品和服务。以下是 DeepSeek 的主要产品和服务介绍：\n\n### **1. DeepSeek 大模型系列**\nDeepSeek 研发了多个强大的大语言模型（LLM），包括：\n- **DeepSeek-V3**：最新一代大语言模型，具备 128K 上下文窗口，支持超长文本理解，擅长代码、数学、逻辑推理和文本创作。\n- **DeepSeek-Coder**：专为编程和代码生成优化的模型，支持多种编程语言，能帮助开发者提高效率。\n- **DeepSeek-Math**：专注于数学推理和...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Function</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>InvokePromptAsync_684d79feb2a14253a8ba83d85bf49c74</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>InvokePromptAsync_684d79feb2a14253a8ba83d85bf49c74</pre></div></td></tr><tr><td>PluginName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Description</td><td><div class="dni-plaintext"><pre>Generic function, unknown purpose</pre></div></td></tr><tr><td>Metadata</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.SemanticKernel.KernelFunctionMetadata</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>InvokePromptAsync_684d79feb2a14253a8ba83d85bf49c74</pre></div></td></tr><tr><td>PluginName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Description</td><td><div class="dni-plaintext"><pre>Generic function, unknown purpose</pre></div></td></tr><tr><td>Parameters</td><td><i>(empty)</i></td></tr><tr><td>ReturnParameter</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.SemanticKernel.KernelReturnParameterMetadata</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Description</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>ParameterType</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Schema</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>AdditionalProperties</td><td><i>(empty)</i></td></tr></tbody></table></div></details></td></tr><tr><td>ExecutionSettings</td><td><i>(empty)</i></td></tr><tr><td>UnderlyingMethod</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Metadata</td><td><table><thead><tr><th><i>key</i></th><th><i>type</i></th><th>value</th></tr></thead><tbody><tr><td><div class="dni-plaintext"><pre>Id</pre></div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-7.0">System.String</a></span></td><td><div class="dni-plaintext"><pre>e5b37485-e8ec-4058-b0ca-0d83e4dee6a7</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>CreatedAt</pre></div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.datetimeoffset?view=net-7.0">System.DateTimeOffset</a></span></td><td><span>2025-04-19 12:41:33Z</span></td></tr><tr><td><div class="dni-plaintext"><pre>SystemFingerprint</pre></div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-7.0">System.String</a></span></td><td><div class="dni-plaintext"><pre>fp_3d5141a69a_prod0225</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>Usage</pre></div></td><td>OpenAI.Chat.ChatTokenUsage</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>OpenAI.Chat.ChatTokenUsage</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>OutputTokenCount</td><td><div class="dni-plaintext"><pre>758</pre></div></td></tr><tr><td>InputTokenCount</td><td><div class="dni-plaintext"><pre>10</pre></div></td></tr><tr><td>TotalTokenCount</td><td><div class="dni-plaintext"><pre>768</pre></div></td></tr><tr><td>OutputTokenDetails</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>InputTokenDetails</td><td>< ...

// %% [markdown]
// ## 指定自定义OpenAIClient

// %%
using Microsoft.SemanticKernel;
using Microsoft.SemanticKernel.ChatCompletion;
using Microsoft.SemanticKernel.Connectors.OpenAI;
using Microsoft.Extensions.DependencyInjection;
using OpenAI;
using System.ClientModel;

// 引入交互式的内核命名空间，以便用户输入

using PolyglotKernel= Microsoft.DotNet.Interactive.Kernel;

// var deepseekApiKey = await PolyglotKernel.GetInputAsync("请输入您的API Key："); 
var deepseekApiKey = "sk-de7d2bdb6f1b428ea23d4c4b8176b6dc";


// Create kernel builder
var builder = Kernel.CreateBuilder();

var endpoint = new Uri("https://api.deepseek.com");
OpenAIClientOptions clientOptions = new OpenAIClientOptions();
clientOptions.Endpoint = endpoint;

// 创建自定义的OpenAI客户端
OpenAIClient client = new(new ApiKeyCredential(deepseekApiKey), clientOptions);

// Add OpenAI Chat completion
builder.AddOpenAIChatCompletion(
    modelId: "deepseek-reasoner", // 可选模型编码：deepseek-chat、deepseek-reasoner（推理）
    openAIClient: client);

// Build kernel
var kernel = builder.Build();

var response = await kernel.InvokePromptAsync("啥是Semantic Kernel");
response.Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>**Semantic Kernel（语义内核）详解**\n\n**1. 定义与背景**  \nSemantic Kernel（SK）是由微软开发的开源SDK，旨在简化AI技术与传统编程的融合。它通过结合大语言模型（如GPT）与传统代码，帮助开发者高效构建智能应用，适用于自动化、数据分析等场景。\n\n**2. 核心功能与概念**  \n- **语义函数**：用自然语言编写的提示词（如“总结以下文本”），调用AI模型处理任务。  \n- **原生函数**：传统代码（如C#/Python），处理数据、API调用等确定性任务。  \n- **编排器**：协调多个函数，形成工作流（例如先翻译再生成摘要...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Function</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>InvokePromptAsync_aec1c11296dd436e8af7af64255a05a0</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>InvokePromptAsync_aec1c11296dd436e8af7af64255a05a0</pre></div></td></tr><tr><td>PluginName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Description</td><td><div class="dni-plaintext"><pre>Generic function, unknown purpose</pre></div></td></tr><tr><td>Metadata</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.SemanticKernel.KernelFunctionMetadata</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>InvokePromptAsync_aec1c11296dd436e8af7af64255a05a0</pre></div></td></tr><tr><td>PluginName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Description</td><td><div class="dni-plaintext"><pre>Generic function, unknown purpose</pre></div></td></tr><tr><td>Parameters</td><td><i>(empty)</i></td></tr><tr><td>ReturnParameter</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.SemanticKernel.KernelReturnParameterMetadata</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Description</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>ParameterType</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Schema</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>AdditionalProperties</td><td><i>(empty)</i></td></tr></tbody></table></div></details></td></tr><tr><td>ExecutionSettings</td><td><i>(empty)</i></td></tr><tr><td>UnderlyingMethod</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Metadata</td><td><table><thead><tr><th><i>key</i></th><th><i>type</i></th><th>value</th></tr></thead><tbody><tr><td><div class="dni-plaintext"><pre>Id</pre></div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-7.0">System.String</a></span></td><td><div class="dni-plaintext"><pre>883a9c3a-e739-48eb-8fb0-e082f08478a9</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>CreatedAt</pre></div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.datetimeoffset?view=net-7.0">System.DateTimeOffset</a></span></td><td><span>2025-04-19 12:43:19Z</span></td></tr><tr><td><div class="dni-plaintext"><pre>SystemFingerprint</pre></div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-7.0">System.String</a></span></td><td><div class="dni-plaintext"><pre>fp_5417b77867_prod0225</pre></div></td></tr><tr><td><div class="dni-plaintext"><pre>Usage</pre></div></td><td>OpenAI.Chat.ChatTokenUsage</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>OpenAI.Chat.ChatTokenUsage</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>OutputTokenCount</td><td><div class="dni-plaintext"><pre>1428</pre></div></td></tr><tr><td>InputTokenCount</td><td><div class="dni-plaintext"><pre>10</pre></div></td></tr><tr><td>TotalTokenCount</td><td><div class="dni-plaintext"><pre>1438</pre></div></td></tr><tr><td>OutputTokenDetails</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>OpenAI.Chat.ChatOutputToke ...
